# %%
import sys
sys.path.append('..')

from sequencer import Sequencer

# Test it
seq = Sequencer("TEST", "ATCG", "hg38", "human", "illumina")
print(seq)
seq
# Out:
# Patient ID: TEST /n Length: 4 bp /n Organism: human
# Sequencer(pid = 'TEST', sequence = ATCG, refgenome = hg38, organism = human, technology = illumina)
