# %%
import sys
sys.path.append(r"C:/Users/Kudashian/My Drive/TheToolShed/bioseq")

from Sequencer import Sequencer, FastaReader

# %%
with FastaReader('./testData/PGX023C_S2_L001_R1_001.fastq.gz') as reader:
    controls = []
    for seq in reader:
        if seq.pid.upper().endswith('_C'):
            controls.append(seq)

print(f"Found {len(controls)} control sequences.")
# Out:
# Found 2 control sequences.
